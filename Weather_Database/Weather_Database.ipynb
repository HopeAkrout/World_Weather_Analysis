# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

        # Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | coquimbo
# Processing Record 4 of Set 1 | babu
# Processing Record 5 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | wilmington
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | port-gentil
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | saint-augustin
# Processing Record 14 of Set 1 | tillabery
# City not found. Skipping...
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | madison
# Processing Record 17 of Set 1 | bengkulu
# Processing Record 18 of Set 1 | pierre
# Processing Record 19 of Set 1 | tias
# Processing Record 20 of Set 1 | kheri
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | puerto escondido
# Processing Record 24 of Set 1 | kutum
# Processing Record 25 of Set 1 | poum
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | lebu
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | kehtna
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | sandwick
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | seymchan
# Processing Record 35 of Set 1 | jackson
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | iqaluit
# Processing Record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 1 | freeport
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | bengkalis
# City not found. Skipping...
# Processing Record 42 of Set 1 | ibra
# Processing Record 43 of Set 1 | melfi
# Processing Record 44 of Set 1 | kundiawa
# Processing Record 45 of Set 1 | lagoa
# Processing Record 46 of Set 1 | provideniya
# Processing Record 47 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 1 | ust-kut
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | caravelas
# Processing Record 1 of Set 2 | houston
# Processing Record 2 of Set 2 | tasiilaq
# Processing Record 3 of Set 2 | yuzhno-sukhokumsk
# Processing Record 4 of Set 2 | gorodishche
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | konya
# Processing Record 7 of Set 2 | tiksi
# Processing Record 8 of Set 2 | cedar city
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | ca mau
# Processing Record 11 of Set 2 | clyde river
# Processing Record 12 of Set 2 | kinkala
# Processing Record 13 of Set 2 | husavik
# Processing Record 14 of Set 2 | storm lake
# Processing Record 15 of Set 2 | banda aceh
# Processing Record 16 of Set 2 | mantua
# Processing Record 17 of Set 2 | tam ky
# Processing Record 18 of Set 2 | norman wells
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | huilong
# Processing Record 21 of Set 2 | gizo
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | herat
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 2 | palenque
# Processing Record 26 of Set 2 | santiago del estero
# Processing Record 27 of Set 2 | yuanping
# Processing Record 28 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | ayan
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | belle fourche
# Processing Record 33 of Set 2 | nikolskoye
# Processing Record 34 of Set 2 | lavrentiya
# Processing Record 35 of Set 2 | bar
# Processing Record 36 of Set 2 | souillac
# Processing Record 37 of Set 2 | saint anthony
# Processing Record 38 of Set 2 | flin flon
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | chokurdakh
# Processing Record 41 of Set 2 | sioux lookout
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | ostrovnoy
# Processing Record 44 of Set 2 | dwarka
# Processing Record 45 of Set 2 | zaysan
# Processing Record 46 of Set 2 | uige
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | fortuna
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | svencioneliai
# Processing Record 3 of Set 3 | rocky mountain house
# Processing Record 4 of Set 3 | kahului
# Processing Record 5 of Set 3 | kasungu
# Processing Record 6 of Set 3 | kapatan
# Processing Record 7 of Set 3 | christchurch
# Processing Record 8 of Set 3 | khandyga
# Processing Record 9 of Set 3 | kieta
# Processing Record 10 of Set 3 | tuatapere
# Processing Record 11 of Set 3 | itanagar
# Processing Record 12 of Set 3 | lata
# Processing Record 13 of Set 3 | bubaque
# Processing Record 14 of Set 3 | nouadhibou
# Processing Record 15 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 3 | aransas pass
# Processing Record 17 of Set 3 | yellowknife
# Processing Record 18 of Set 3 | adrar
# Processing Record 19 of Set 3 | vila velha
# Processing Record 20 of Set 3 | takoradi
# Processing Record 21 of Set 3 | ancud
# Processing Record 22 of Set 3 | kroya
# Processing Record 23 of Set 3 | yatou
# Processing Record 24 of Set 3 | devils lake
# Processing Record 25 of Set 3 | xichang
# Processing Record 26 of Set 3 | chernushka
# Processing Record 27 of Set 3 | aklavik
# Processing Record 28 of Set 3 | hobart
# Processing Record 29 of Set 3 | punta arenas
# Processing Record 30 of Set 3 | saint george
# Processing Record 31 of Set 3 | lompoc
# Processing Record 32 of Set 3 | longyearbyen
# Processing Record 33 of Set 3 | ndele
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | knysna
# Processing Record 36 of Set 3 | cherskiy
# Processing Record 37 of Set 3 | lincoln
# Processing Record 38 of Set 3 | belyy yar
# Processing Record 39 of Set 3 | puerto del rosario
# Processing Record 40 of Set 3 | talnakh
# Processing Record 41 of Set 3 | fairbanks
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | georgetown
# Processing Record 44 of Set 3 | severo-kurilsk
# Processing Record 45 of Set 3 | si racha
# Processing Record 46 of Set 3 | ouidah
# Processing Record 47 of Set 3 | suzhou
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | bethel
# Processing Record 50 of Set 3 | fayetteville
# Processing Record 1 of Set 4 | ilhabela
# Processing Record 2 of Set 4 | klimovo
# Processing Record 3 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 4 | wanning
# Processing Record 5 of Set 4 | verkhnevilyuysk
# Processing Record 6 of Set 4 | karratha
# Processing Record 7 of Set 4 | meulaboh
# Processing Record 8 of Set 4 | campos belos
# Processing Record 9 of Set 4 | nador
# Processing Record 10 of Set 4 | ahuimanu
# Processing Record 11 of Set 4 | tilichiki
# Processing Record 12 of Set 4 | chuy
# Processing Record 13 of Set 4 | grindavik
# Processing Record 14 of Set 4 | galesong
# Processing Record 15 of Set 4 | katyuzhanka
# Processing Record 16 of Set 4 | vuktyl
# Processing Record 17 of Set 4 | saldanha
# Processing Record 18 of Set 4 | singaraja
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | kamenka
# Processing Record 21 of Set 4 | haines junction
# Processing Record 22 of Set 4 | lorengau
# Processing Record 23 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 25 of Set 4 | margate
# Processing Record 26 of Set 4 | barrow
# Processing Record 27 of Set 4 | luderitz
# Processing Record 28 of Set 4 | harper
# Processing Record 29 of Set 4 | ballina
# Processing Record 30 of Set 4 | khatanga
# Processing Record 31 of Set 4 | faanui
# Processing Record 32 of Set 4 | sao jose da coroa grande
# Processing Record 33 of Set 4 | nome
# Processing Record 34 of Set 4 | carauari
# Processing Record 35 of Set 4 | bitkine
# Processing Record 36 of Set 4 | katsuura
# Processing Record 37 of Set 4 | apatou
# Processing Record 38 of Set 4 | turayf
# Processing Record 39 of Set 4 | quatre cocos
# Processing Record 40 of Set 4 | nosy varika
# Processing Record 41 of Set 4 | curuguaty
# Processing Record 42 of Set 4 | los llanos de aridane
# Processing Record 43 of Set 4 | hithadhoo
# Processing Record 44 of Set 4 | forest grove
# Processing Record 45 of Set 4 | chincha alta
# Processing Record 46 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 4 | awjilah
# Processing Record 48 of Set 4 | kuytun
# Processing Record 49 of Set 4 | vestbygda
# City not found. Skipping...
# Processing Record 50 of Set 4 | eldoret
# Processing Record 1 of Set 5 | olovyannaya
# Processing Record 2 of Set 5 | itaituba
# Processing Record 3 of Set 5 | rudbar
# Processing Record 4 of Set 5 | ilulissat
# Processing Record 5 of Set 5 | marzuq
# Processing Record 6 of Set 5 | dukat
# Processing Record 7 of Set 5 | wairoa
# Processing Record 8 of Set 5 | lima
# Processing Record 9 of Set 5 | san quintin
# Processing Record 10 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 5 | bandarbeyla
# Processing Record 12 of Set 5 | cidreira
# Processing Record 13 of Set 5 | gopichettipalaiyam
# City not found. Skipping...
# Processing Record 14 of Set 5 | lucapa
# Processing Record 15 of Set 5 | kavieng
# Processing Record 16 of Set 5 | porbandar
# Processing Record 17 of Set 5 | kaitangata
# Processing Record 18 of Set 5 | chojnice
# Processing Record 19 of Set 5 | parana
# Processing Record 20 of Set 5 | mandalgovi
# Processing Record 21 of Set 5 | salalah
# Processing Record 22 of Set 5 | buala
# Processing Record 23 of Set 5 | coihaique
# Processing Record 24 of Set 5 | buta
# Processing Record 25 of Set 5 | port lincoln
# Processing Record 26 of Set 5 | abu dhabi
# Processing Record 27 of Set 5 | victoria
# Processing Record 28 of Set 5 | leningradskiy
# Processing Record 29 of Set 5 | mar del plata
# Processing Record 30 of Set 5 | nemuro
# Processing Record 31 of Set 5 | rabo de peixe
# Processing Record 32 of Set 5 | road town
# Processing Record 33 of Set 5 | san carlos
# Processing Record 34 of Set 5 | ambilobe
# Processing Record 35 of Set 5 | juneau
# Processing Record 36 of Set 5 | torbay
# Processing Record 37 of Set 5 | carlsbad
# Processing Record 38 of Set 5 | anuradhapura
# Processing Record 39 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 5 | tuktoyaktuk
# Processing Record 41 of Set 5 | tiarei
# Processing Record 42 of Set 5 | mizque
# Processing Record 43 of Set 5 | zwedru
# Processing Record 44 of Set 5 | salinas
# Processing Record 45 of Set 5 | naryan-mar
# Processing Record 46 of Set 5 | kavaratti
# Processing Record 47 of Set 5 | mount gambier
# Processing Record 48 of Set 5 | mana
# Processing Record 49 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 50 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 6 | carnarvon
# Processing Record 2 of Set 6 | ixtapa
# Processing Record 3 of Set 6 | buin
# Processing Record 4 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 5 of Set 6 | cabo san lucas
# Processing Record 6 of Set 6 | bindi
# Processing Record 7 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 8 of Set 6 | nanortalik
# Processing Record 9 of Set 6 | sitka
# Processing Record 10 of Set 6 | shirgaon
# Processing Record 11 of Set 6 | namibe
# Processing Record 12 of Set 6 | kirn
# Processing Record 13 of Set 6 | oksfjord
# Processing Record 14 of Set 6 | giyani
# Processing Record 15 of Set 6 | ribeira grande
# Processing Record 16 of Set 6 | nioro
# Processing Record 17 of Set 6 | thinadhoo
# Processing Record 18 of Set 6 | eregli
# Processing Record 19 of Set 6 | bilma
# Processing Record 20 of Set 6 | acapulco
# Processing Record 21 of Set 6 | medea
# Processing Record 22 of Set 6 | cayenne
# Processing Record 23 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 6 | floro
# Processing Record 25 of Set 6 | praia
# Processing Record 26 of Set 6 | klaksvik
# Processing Record 27 of Set 6 | hofn
# Processing Record 28 of Set 6 | praya
# Processing Record 29 of Set 6 | banes
# Processing Record 30 of Set 6 | gualaco
# Processing Record 31 of Set 6 | san cristobal
# Processing Record 32 of Set 6 | qandala
# Processing Record 33 of Set 6 | pemangkat
# Processing Record 34 of Set 6 | karangampel
# Processing Record 35 of Set 6 | banyo
# Processing Record 36 of Set 6 | date
# Processing Record 37 of Set 6 | zhigansk
# Processing Record 38 of Set 6 | karaton
# Processing Record 39 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 6 | mbour
# Processing Record 41 of Set 6 | mahebourg
# Processing Record 42 of Set 6 | saint-ambroise
# Processing Record 43 of Set 6 | santa vitoria do palmar
# Processing Record 44 of Set 6 | correntina
# Processing Record 45 of Set 6 | mahon
# Processing Record 46 of Set 6 | morondava
# Processing Record 47 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 48 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 49 of Set 6 | eureka
# Processing Record 50 of Set 6 | kabo
# Processing Record 1 of Set 7 | mecca
# Processing Record 2 of Set 7 | penalva
# Processing Record 3 of Set 7 | kuusamo
# Processing Record 4 of Set 7 | chapais
# Processing Record 5 of Set 7 | hambantota
# Processing Record 6 of Set 7 | bonavista
# Processing Record 7 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 8 of Set 7 | kloulklubed
# Processing Record 9 of Set 7 | isangel
# Processing Record 10 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 7 | dehloran
# Processing Record 12 of Set 7 | phangnga
# Processing Record 13 of Set 7 | buraydah
# Processing Record 14 of Set 7 | fort nelson
# Processing Record 15 of Set 7 | jurado
# Processing Record 16 of Set 7 | acari
# Processing Record 17 of Set 7 | dauphin
# Processing Record 18 of Set 7 | halifax
# Processing Record 19 of Set 7 | moses lake
# Processing Record 20 of Set 7 | olafsvik
# Processing Record 21 of Set 7 | nuuk
# Processing Record 22 of Set 7 | mangai
# Processing Record 23 of Set 7 | namatanai
# Processing Record 24 of Set 7 | praia da vitoria
# Processing Record 25 of Set 7 | ertil
# Processing Record 26 of Set 7 | myitkyina
# Processing Record 27 of Set 7 | codrington
# Processing Record 28 of Set 7 | ji-parana
# City not found. Skipping...
# Processing Record 29 of Set 7 | marienburg
# Processing Record 30 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 7 | dalvik
# Processing Record 32 of Set 7 | soderhamn
# Processing Record 33 of Set 7 | dingle
# Processing Record 34 of Set 7 | misratah
# Processing Record 35 of Set 7 | patos
# Processing Record 36 of Set 7 | ahipara
# Processing Record 37 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 7 | hermiston
# Processing Record 41 of Set 7 | prainha
# Processing Record 42 of Set 7 | abnub
# Processing Record 43 of Set 7 | porosozero
# Processing Record 44 of Set 7 | lazurne
# Processing Record 45 of Set 7 | geraldton
# Processing Record 46 of Set 7 | yar-sale
# Processing Record 47 of Set 7 | richards bay
# Processing Record 48 of Set 7 | jacareacanga
# Processing Record 49 of Set 7 | ormara
# Processing Record 50 of Set 7 | big spring
# Processing Record 1 of Set 8 | sheboygan
# Processing Record 2 of Set 8 | sao joao da barra
# Processing Record 3 of Set 8 | hohhot
# Processing Record 4 of Set 8 | kodiak
# Processing Record 5 of Set 8 | arti
# Processing Record 6 of Set 8 | eirunepe
# Processing Record 7 of Set 8 | mendi
# Processing Record 8 of Set 8 | morgan city
# Processing Record 9 of Set 8 | prince rupert
# Processing Record 10 of Set 8 | karlskrona
# Processing Record 11 of Set 8 | yumen
# Processing Record 12 of Set 8 | taoudenni
# Processing Record 13 of Set 8 | udachnyy
# Processing Record 14 of Set 8 | wundanyi
# Processing Record 15 of Set 8 | pevek
# Processing Record 16 of Set 8 | esperance
# Processing Record 17 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 18 of Set 8 | mount isa
# Processing Record 19 of Set 8 | zyryanka
# Processing Record 20 of Set 8 | beloha
# Processing Record 21 of Set 8 | pitiquito
# Processing Record 22 of Set 8 | banjarmasin
# Processing Record 23 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 8 | rio de janeiro
# Processing Record 25 of Set 8 | biak
# Processing Record 26 of Set 8 | funtua
# Processing Record 27 of Set 8 | hualmay
# Processing Record 28 of Set 8 | country club
# Processing Record 29 of Set 8 | jardim
# Processing Record 30 of Set 8 | chernyshevskiy
# Processing Record 31 of Set 8 | weligama
# Processing Record 32 of Set 8 | abilene
# Processing Record 33 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 34 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 8 | foumban
# Processing Record 36 of Set 8 | vardo
# Processing Record 37 of Set 8 | ler
# Processing Record 38 of Set 8 | shishou
# Processing Record 39 of Set 8 | aracaju
# Processing Record 40 of Set 8 | boueni
# Processing Record 41 of Set 8 | del rio
# Processing Record 42 of Set 8 | vetlanda
# Processing Record 43 of Set 8 | beringovskiy
# Processing Record 44 of Set 8 | bosaso
# Processing Record 45 of Set 8 | oussouye
# Processing Record 46 of Set 8 | victor harbor
# Processing Record 47 of Set 8 | gat
# Processing Record 48 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 8 | buarcos
# Processing Record 50 of Set 8 | alvdal
# Processing Record 1 of Set 9 | kaeo
# Processing Record 2 of Set 9 | mut
# Processing Record 3 of Set 9 | severodvinsk
# Processing Record 4 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 9 | ouahigouya
# Processing Record 6 of Set 9 | tymovskoye
# Processing Record 7 of Set 9 | ust-nera
# Processing Record 8 of Set 9 | yulara
# Processing Record 9 of Set 9 | tateyama
# Processing Record 10 of Set 9 | nordhausen
# Processing Record 11 of Set 9 | kamaishi
# Processing Record 12 of Set 9 | asfi
# Processing Record 13 of Set 9 | khudumelapye
# Processing Record 14 of Set 9 | ngunguru
# Processing Record 15 of Set 9 | port moresby
# Processing Record 16 of Set 9 | sao joao de pirabas
# Processing Record 17 of Set 9 | nikki
# Processing Record 18 of Set 9 | hasaki
# Processing Record 19 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 9 | vilhena
# Processing Record 21 of Set 9 | gorin
# Processing Record 22 of Set 9 | kruisfontein
# Processing Record 23 of Set 9 | roma
# Processing Record 24 of Set 9 | muriae
# Processing Record 25 of Set 9 | la ronge
# Processing Record 26 of Set 9 | derzhavinsk
# Processing Record 27 of Set 9 | conselheiro pena
# Processing Record 28 of Set 9 | crateus
# Processing Record 29 of Set 9 | hamilton
# Processing Record 30 of Set 9 | gigmoto
# Processing Record 31 of Set 9 | vao
# Processing Record 32 of Set 9 | baykit
# Processing Record 33 of Set 9 | izhma
# Processing Record 34 of Set 9 | kapoeta
# Processing Record 35 of Set 9 | constitucion
# Processing Record 36 of Set 9 | envira
# Processing Record 37 of Set 9 | surt
# Processing Record 38 of Set 9 | vanimo
# Processing Record 39 of Set 9 | bethanien
# Processing Record 40 of Set 9 | alice springs
# Processing Record 41 of Set 9 | general pico
# Processing Record 42 of Set 9 | koratla
# Processing Record 43 of Set 9 | narsaq
# Processing Record 44 of Set 9 | broome
# Processing Record 45 of Set 9 | villena
# Processing Record 46 of Set 9 | safaga
# Processing Record 47 of Set 9 | umm lajj
# Processing Record 48 of Set 9 | saint pete beach
# Processing Record 49 of Set 9 | dax
# Processing Record 50 of Set 9 | myaundzha
# Processing Record 1 of Set 10 | marawi
# Processing Record 2 of Set 10 | yinchuan
# Processing Record 3 of Set 10 | shahr-e babak
# Processing Record 4 of Set 10 | port blair
# Processing Record 5 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 10 | trincomalee
# Processing Record 7 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 8 of Set 10 | shenjiamen
# Processing Record 9 of Set 10 | mudanjiang
# Processing Record 10 of Set 10 | mocuba
# Processing Record 11 of Set 10 | bam
# Processing Record 12 of Set 10 | sayville
# Processing Record 13 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 10 | dawlatabad
# Processing Record 15 of Set 10 | nantucket
# Processing Record 16 of Set 10 | weiser
# Processing Record 17 of Set 10 | port hardy
# Processing Record 18 of Set 10 | atambua
# Processing Record 19 of Set 10 | seoul
# Processing Record 20 of Set 10 | port shepstone
# Processing Record 21 of Set 10 | san policarpo
# Processing Record 22 of Set 10 | pisco
# Processing Record 23 of Set 10 | tessalit
# Processing Record 24 of Set 10 | faya
# Processing Record 25 of Set 10 | puerto pinasco
# City not found. Skipping...
# Processing Record 26 of Set 10 | puerto baquerizo moreno
# Processing Record 27 of Set 10 | asau
# Processing Record 28 of Set 10 | guerrero negro
# Processing Record 29 of Set 10 | comodoro rivadavia
# Processing Record 30 of Set 10 | ayr
# Processing Record 31 of Set 10 | visby
# Processing Record 32 of Set 10 | balykshi
# Processing Record 33 of Set 10 | volsk
# Processing Record 34 of Set 10 | yantal
# Processing Record 35 of Set 10 | playa del carmen
# Processing Record 36 of Set 10 | bulgan
# Processing Record 37 of Set 10 | anadyr
# Processing Record 38 of Set 10 | moranbah
# Processing Record 39 of Set 10 | kelvington
# Processing Record 40 of Set 10 | curico
# Processing Record 41 of Set 10 | alofi
# Processing Record 42 of Set 10 | burley
# Processing Record 43 of Set 10 | laizhou
# Processing Record 44 of Set 10 | binzhou
# Processing Record 45 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 10 | westport
# Processing Record 47 of Set 10 | vestmannaeyjar
# Processing Record 48 of Set 10 | waipawa
# Processing Record 49 of Set 10 | george
# Processing Record 50 of Set 10 | key west
# Processing Record 1 of Set 11 | kungurtug
# Processing Record 2 of Set 11 | batticaloa
# Processing Record 3 of Set 11 | stromness
# Processing Record 4 of Set 11 | half moon bay
# Processing Record 5 of Set 11 | namestovo
# Processing Record 6 of Set 11 | hun
# Processing Record 7 of Set 11 | tawau
# Processing Record 8 of Set 11 | hobyo
# Processing Record 9 of Set 11 | taltal
# Processing Record 10 of Set 11 | naze
# Processing Record 11 of Set 11 | shenxian
# Processing Record 12 of Set 11 | kununurra
# Processing Record 13 of Set 11 | gamba
# Processing Record 14 of Set 11 | punta cardon
# Processing Record 15 of Set 11 | khandbari
# Processing Record 16 of Set 11 | bogota
# Processing Record 17 of Set 11 | mgachi
# Processing Record 18 of Set 11 | caldwell
# Processing Record 19 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 20 of Set 11 | burla
# Processing Record 21 of Set 11 | burnie
# Processing Record 22 of Set 11 | shakhovskaya
# Processing Record 23 of Set 11 | dabakala
# Processing Record 24 of Set 11 | murdochville
# Processing Record 25 of Set 11 | mocorito
# Processing Record 26 of Set 11 | mangaratiba
# Processing Record 27 of Set 11 | ayagoz
# Processing Record 28 of Set 11 | umm jarr
# City not found. Skipping...
# Processing Record 29 of Set 11 | lashio
# Processing Record 30 of Set 11 | laguna
# Processing Record 31 of Set 11 | warmbad
# Processing Record 32 of Set 11 | majene
# Processing Record 33 of Set 11 | larsnes
# Processing Record 34 of Set 11 | sorland
# Processing Record 35 of Set 11 | grand gaube
# Processing Record 36 of Set 11 | shimoda
# Processing Record 37 of Set 11 | toamasina
# Processing Record 38 of Set 11 | hearst
# Processing Record 39 of Set 11 | komsomolskiy
# Processing Record 40 of Set 11 | bria
# Processing Record 41 of Set 11 | saulkrasti
# Processing Record 42 of Set 11 | alamosa
# Processing Record 43 of Set 11 | russell
# Processing Record 44 of Set 11 | madang
# Processing Record 45 of Set 11 | nocupetaro
# Processing Record 46 of Set 11 | akureyri
# Processing Record 47 of Set 11 | omboue
# Processing Record 48 of Set 11 | ulladulla
# Processing Record 49 of Set 11 | deputatskiy
# Processing Record 50 of Set 11 | san borja
# Processing Record 1 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 12 | mitu
# Processing Record 4 of Set 12 | chapleau
# Processing Record 5 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 6 of Set 12 | inuvik
# Processing Record 7 of Set 12 | okhotsk
# Processing Record 8 of Set 12 | kodinsk
# Processing Record 9 of Set 12 | cap malheureux
# Processing Record 10 of Set 12 | bremerton
# Processing Record 11 of Set 12 | penzance
# Processing Record 12 of Set 12 | thohoyandou
# Processing Record 13 of Set 12 | bangaon
# Processing Record 14 of Set 12 | kinablangan
# Processing Record 15 of Set 12 | constantine
# Processing Record 16 of Set 12 | berlevag
# Processing Record 17 of Set 12 | ayer itam
# City not found. Skipping...
# Processing Record 18 of Set 12 | bucerias
# Processing Record 19 of Set 12 | oyama
# Processing Record 20 of Set 12 | peniche
# Processing Record 21 of Set 12 | iaciara
# Processing Record 22 of Set 12 | diamantina
# Processing Record 23 of Set 12 | menongue
# Processing Record 24 of Set 12 | kushiro
# Processing Record 25 of Set 12 | arrifes
# Processing Record 26 of Set 12 | sembakung
# Processing Record 27 of Set 12 | ostersund
# Processing Record 28 of Set 12 | san patricio
# Processing Record 29 of Set 12 | potosi
# Processing Record 30 of Set 12 | makakilo city
# Processing Record 31 of Set 12 | utrera
# Processing Record 32 of Set 12 | chulman
# Processing Record 33 of Set 12 | lillooet
# Processing Record 34 of Set 12 | bogande
# Processing Record 35 of Set 12 | ola
# Processing Record 36 of Set 12 | solnechnyy
# Processing Record 37 of Set 12 | itagiba
# Processing Record 38 of Set 12 | gidam
# Processing Record 39 of Set 12 | betare oya
# Processing Record 40 of Set 12 | miles city
# Processing Record 41 of Set 12 | los andes
# Processing Record 42 of Set 12 | carolina
# Processing Record 43 of Set 12 | cleveland
# Processing Record 44 of Set 12 | cabedelo
# Processing Record 45 of Set 12 | perene
# Processing Record 46 of Set 12 | kwinana
# Processing Record 47 of Set 12 | cockburn town
# Processing Record 48 of Set 12 | stephenville
# Processing Record 49 of Set 12 | nabire
# Processing Record 50 of Set 12 | yangjiang
# Processing Record 1 of Set 13 | ternate
# Processing Record 2 of Set 13 | rio gallegos
# Processing Record 3 of Set 13 | sokoni
# Processing Record 4 of Set 13 | bay roberts
# Processing Record 5 of Set 13 | talara
# Processing Record 6 of Set 13 | quesnel
# Processing Record 7 of Set 13 | atar
# Processing Record 8 of Set 13 | balabac
# Processing Record 9 of Set 13 | broken hill
# Processing Record 10 of Set 13 | vedaranniyam
# City not found. Skipping...
# Processing Record 11 of Set 13 | the valley
# Processing Record 12 of Set 13 | murgab
# Processing Record 13 of Set 13 | dawei
# Processing Record 14 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 13 | babaeski
# Processing Record 16 of Set 13 | rehoboth
# Processing Record 17 of Set 13 | green river
# Processing Record 18 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 13 | barabai
# Processing Record 20 of Set 13 | vyazniki
# Processing Record 21 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 22 of Set 13 | manaure
# Processing Record 23 of Set 13 | vila franca do campo
# Processing Record 24 of Set 13 | dunedin
# Processing Record 25 of Set 13 | novobirilyussy
# Processing Record 26 of Set 13 | khash
# Processing Record 27 of Set 13 | saint cloud
# Processing Record 28 of Set 13 | conde
# Processing Record 29 of Set 13 | byron bay
# Processing Record 30 of Set 13 | muros
# Processing Record 31 of Set 13 | moose factory
# Processing Record 32 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 13 | moerai
# Processing Record 34 of Set 13 | nicolas bravo
# Processing Record 35 of Set 13 | quang ngai
# Processing Record 36 of Set 13 | jian
# Processing Record 37 of Set 13 | waitati
# Processing Record 38 of Set 13 | los zacatones
# Processing Record 39 of Set 13 | farah
# Processing Record 40 of Set 13 | ketchikan
# Processing Record 41 of Set 13 | kimbe
# Processing Record 42 of Set 13 | doka
# Processing Record 43 of Set 13 | los corrales de buelna
# Processing Record 44 of Set 13 | codo
# Processing Record 45 of Set 13 | andernach
# Processing Record 46 of Set 13 | villalba
# Processing Record 47 of Set 13 | lerwick
# Processing Record 48 of Set 13 | tigil
# Processing Record 49 of Set 13 | smila
# Processing Record 50 of Set 13 | shelburne
# Processing Record 1 of Set 14 | imeni poliny osipenko
# Processing Record 2 of Set 14 | vestmanna
# Processing Record 3 of Set 14 | kisangani
# Processing Record 4 of Set 14 | huarmey
# Processing Record 5 of Set 14 | homer
# Processing Record 6 of Set 14 | sao filipe
# Processing Record 7 of Set 14 | niksic
# Processing Record 8 of Set 14 | ranong
# Processing Record 9 of Set 14 | mackay
# Processing Record 10 of Set 14 | srednekolymsk
# Processing Record 11 of Set 14 | coahuayana
# Processing Record 12 of Set 14 | newport
# Processing Record 13 of Set 14 | namie
# Processing Record 14 of Set 14 | brownsville
# Processing Record 15 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 14 | kipit
# Processing Record 17 of Set 14 | bontang
# Processing Record 18 of Set 14 | rio grande city
# Processing Record 19 of Set 14 | fonte boa
# Processing Record 20 of Set 14 | shenzhen
# Processing Record 21 of Set 14 | severnyy
# Processing Record 22 of Set 14 | kangaatsiaq
# Processing Record 23 of Set 14 | benito juarez
# Processing Record 24 of Set 14 | tabuk
# Processing Record 25 of Set 14 | amapa
# Processing Record 26 of Set 14 | sulangan
# Processing Record 27 of Set 14 | satinka
# Processing Record 28 of Set 14 | sept-iles
# Processing Record 29 of Set 14 | tepechitlan
# Processing Record 30 of Set 14 | aksarka
# Processing Record 31 of Set 14 | kachug
# Processing Record 32 of Set 14 | batagay-alyta
# Processing Record 33 of Set 14 | colesberg
# Processing Record 34 of Set 14 | tangi
# Processing Record 35 of Set 14 | camacha
# Processing Record 36 of Set 14 | pangody
# Processing Record 37 of Set 14 | alyangula
# Processing Record 38 of Set 14 | hami
# Processing Record 39 of Set 14 | rocha
# Processing Record 40 of Set 14 | paso de los toros
# Processing Record 41 of Set 14 | burica
# City not found. Skipping...
# Processing Record 42 of Set 14 | pueblo nuevo
# Processing Record 43 of Set 14 | barroualie
# City not found. Skipping...
# Processing Record 44 of Set 14 | revelstoke
# Processing Record 45 of Set 14 | talaya
# Processing Record 46 of Set 14 | pringsewu
# Processing Record 47 of Set 14 | assiniboia
# Processing Record 48 of Set 14 | aras
# Processing Record 49 of Set 14 | vostok
# Processing Record 50 of Set 14 | tsabong
# Processing Record 1 of Set 15 | sovetskiy
# Processing Record 2 of Set 15 | turbat
# Processing Record 3 of Set 15 | tura
# Processing Record 4 of Set 15 | sansai
# City not found. Skipping...
# Processing Record 5 of Set 15 | kudahuvadhoo
# Processing Record 6 of Set 15 | el tigre
# Processing Record 7 of Set 15 | kingisepp
# Processing Record 8 of Set 15 | taitung
# Processing Record 9 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 10 of Set 15 | huari
# Processing Record 11 of Set 15 | yeppoon
# Processing Record 12 of Set 15 | qaqortoq
# Processing Record 13 of Set 15 | oranjemund
# Processing Record 14 of Set 15 | angoche
# Processing Record 15 of Set 15 | nyurba
# Processing Record 16 of Set 15 | orcopampa
# Processing Record 17 of Set 15 | semnan
# Processing Record 18 of Set 15 | villa bruzual
# Processing Record 19 of Set 15 | te anau
# Processing Record 20 of Set 15 | longyan
# Processing Record 21 of Set 15 | kotelnich
# Processing Record 22 of Set 15 | norfolk
# Processing Record 23 of Set 15 | conakry
# Processing Record 24 of Set 15 | sedona
# Processing Record 25 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 15 | minot
# Processing Record 27 of Set 15 | maldonado
# Processing Record 28 of Set 15 | havelock
# Processing Record 29 of Set 15 | valley city
# Processing Record 30 of Set 15 | sinnamary
# Processing Record 31 of Set 15 | ingham
# Processing Record 32 of Set 15 | qui nhon
# Processing Record 33 of Set 15 | berdigestyakh
# Processing Record 34 of Set 15 | saleilua
# City not found. Skipping...
# Processing Record 35 of Set 15 | san pedro
# Processing Record 36 of Set 15 | karpuninskiy
# City not found. Skipping...
# Processing Record 37 of Set 15 | college
# Processing Record 38 of Set 15 | dryden
# Processing Record 39 of Set 15 | fare
# Processing Record 40 of Set 15 | saint-georges
# Processing Record 41 of Set 15 | bara
# Processing Record 42 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 43 of Set 15 | taywarah
# Processing Record 44 of Set 15 | new iberia
# Processing Record 45 of Set 15 | mogadishu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 680

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0           Atuona  -9.8000 -139.0333     77.40           clear sky        70
# 1             Hilo  19.7297 -155.0900     81.28       moderate rain        93
# 2         Coquimbo -29.9533  -71.3436     55.13     overcast clouds        76
# 3             Babu  24.4167  111.5167     92.17           clear sky        57
# 4          Rikitea -23.1203 -134.9692     74.21          light rain        79
# 5       Wilmington  34.2257  -77.9447     82.31    scattered clouds        87
# 6  Bambous Virieux -20.3428   57.7575     70.21          light rain        70
# 7      Port-Gentil  -0.7193    8.7815     73.67       broken clouds        85
# 8           Avarua -21.2078 -159.7750     75.25    scattered clouds        73
# 9       Butaritari   3.0707  172.7902     81.70       broken clouds        75
#
#    Cloudiness  Wind Speed Country
# 0           1       13.94      PF
# 1         100        3.44      US
# 2         100        0.00      CL
# 3           4        2.91      CN
# 4          99       23.64      PF
# 5          40       10.36      US
# 6          78       16.89      MU
# 7          84       15.01      GA
# 8          40       18.41      CK
# 9          51        6.89      KI

# %%
# reorder columns as City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Atuona      PF  -9.8000 -139.0333     77.40        70           1
# 1             Hilo      US  19.7297 -155.0900     81.28        93         100
# 2         Coquimbo      CL -29.9533  -71.3436     55.13        76         100
# 3             Babu      CN  24.4167  111.5167     92.17        57           4
# 4          Rikitea      PF -23.1203 -134.9692     74.21        79          99
# 5       Wilmington      US  34.2257  -77.9447     82.31        87          40
# 6  Bambous Virieux      MU -20.3428   57.7575     70.21        70          78
# 7      Port-Gentil      GA  -0.7193    8.7815     73.67        85          84
# 8           Avarua      CK -21.2078 -159.7750     75.25        73          40
# 9       Butaritari      KI   3.0707  172.7902     81.70        75          51
#
#    Wind Speed Current Description
# 0       13.94           clear sky
# 1        3.44       moderate rain
# 2        0.00     overcast clouds
# 3        2.91           clear sky
# 4       23.64          light rain
# 5       10.36    scattered clouds
# 6       16.89          light rain
# 7       15.01       broken clouds
# 8       18.41    scattered clouds
# 9        6.89       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
